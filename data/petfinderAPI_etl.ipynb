# %%
import pandas as pd
import requests

from config import api_key
from config import secret_key

# %%
# see https://curl.trillworks.com/ for curl --> python
# see https://www.petfinder.com/developers/v2/docs/ for API

access_token_query_url = "https://api.petfinder.com/v2/oauth2/token"

parameters = {
  'grant_type': 'client_credentials',
  'client_id': api_key,
  'client_secret': secret_key
}

access_token = requests.post(access_token_query_url, data=parameters).json()["access_token"]

# %%
# curl -H "Authorization: Bearer {YOUR_ACCESS_TOKEN}" GET https://api.petfinder.com/v2/{CATEGORY}/{ACTION}?{parameter_1}={value_1}&{parameter_2}={value_2}

# category = animals | types | organizations
# parameters = type | breed | size | gender | age | color | coat | status | name | organization | location | distance | sort | page | limit


################### Option 1 - Dogs by pages###########################

import time 
import pymongo
import json

data_query_url_base = "https://api.petfinder.com/v2/animals?type=dog&limit=100"
#data_query_url_base = "https://api.petfinder.com/v2/animals?type=cat&limit=100"

mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
#mongo_client = pymongo.MongoClient("mongodb+srv://k9sam:1234@petfinder-qbryn.mongodb.net/test?retryWrites=true")

# mongoDB db name = pets
mongo_pet_db = mongo_client['pets'] 
mongo_pet_collection = mongo_pet_db["dogs_by_page"]


for i in range(100):
    page_parameter = "&page=" + str(i+1)
    data_query_url = data_query_url_base + page_parameter
  
    headers = {
        'Authorization': 'Bearer {}'.format(access_token),
    }

    response = requests.get(data_query_url, headers=headers).json()
    
        # json cleaning
    data = response["animals"]
    
    for item in data:
        
        url = item["url"]
        species = item["species"]
        breed = item["breeds"]["primary"]
        color = item["colors"]["primary"]
        age = item["age"]
        gender = item["gender"]
        size = item["size"]
        coat = item["coat"]
        spayed_neutered = item["attributes"]["spayed_neutered"]
        house_trained = item["attributes"]["house_trained"]
        declawed = item["attributes"]["declawed"]
        special_needs = item["attributes"]["special_needs"]
        shots = item["attributes"]["shots_current"]
        name = item["name"]
        description = item["description"]
        
        if len(item["photos"]) != 0:
            photo = item["photos"][0]["full"]
        else:
            photo = "NULL"        
        
        status = item["status"]
        publish_date = item["published_at"]
        contact_email = item["contact"]["email"]
        contact_phone = item["contact"]["phone"]
        contact_address1 = item["contact"]["address"]["address1"]
        contact_address2 = item["contact"]["address"]["address2"]
        contact_city = item["contact"]["address"]["city"]
        contact_state = item["contact"]["address"]["state"]
        contact_postcode = item["contact"]["address"]["postcode"]
        contact_country = item["contact"]["address"]["country"]
    
        data_dict = {
        "url" : url,
        "species" : species,
        "breed" : breed,
        "color" : color,
        "age" : age,
        "gender" : gender,
        "size" : size,
        "coat" : coat,
        "spayed_neutered" : spayed_neutered,
        "house_trained" : house_trained,
        "declawed" : declawed,
        "special_needs" : special_needs,
        "shots" : shots,
        "name" : name,
        "description" : description,
        "photo" : photo,
        "status" : status,
        "publish_date" : publish_date,
        "contact_email" : contact_email,
        "contact_phone" : contact_phone,
        "contact_address1" : contact_address1,
        "contact_address2" : contact_address2,
        "contact_city" : contact_city,
        "contact_state" : contact_state,
        "contact_postcode" : contact_postcode,
        "contact_country" : contact_country
        }
        
        # Save to json file
        with open("dog_by_page.json", "a") as json_file:
            json.dump(data_dict, json_file)
    
        # save dataFrame to mongoDB
        mongo_pet_collection.insert(data_dict)
        
    #mongo_pet_collection.insert(response["animals"])
    
    print("Saving data from  {}".format(i+1))
        
    time.sleep(2)

    
############# end of option 1 (dogs by page)########################
# Out:
# C:\Users\bbmerci\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:107: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# Saving data from  1
# Saving data from  2
# Saving data from  3
# Saving data from  4
# Saving data from  5
# Saving data from  6
# Saving data from  7
# Saving data from  8
# Saving data from  9
# Saving data from  10
# Saving data from  11
# Saving data from  12
# Saving data from  13
# Saving data from  14
# Saving data from  15
# Saving data from  16
# Saving data from  17
# Saving data from  18
# Saving data from  19
# Saving data from  20
# Saving data from  21
# Saving data from  22
# Saving data from  23
# Saving data from  24
# Saving data from  25
# Saving data from  26
# Saving data from  27
# Saving data from  28
# Saving data from  29
# Saving data from  30
# Saving data from  31
# Saving data from  32
# Saving data from  33
# Saving data from  34
# Saving data from  35
# Saving data from  36
# Saving data from  37
# Saving data from  38
# Saving data from  39
# Saving data from  40
# Saving data from  41
# Saving data from  42
# Saving data from  43
# Saving data from  44
# Saving data from  45
# Saving data from  46
# Saving data from  47
# Saving data from  48
# Saving data from  49
# Saving data from  50
# Saving data from  51
# Saving data from  52
# Saving data from  53
# Saving data from  54
# Saving data from  55
# Saving data from  56
# Saving data from  57
# Saving data from  58
# Saving data from  59
# Saving data from  60
# Saving data from  61
# Saving data from  62
# Saving data from  63
# Saving data from  64
# Saving data from  65
# Saving data from  66
# Saving data from  67
# Saving data from  68
# Saving data from  69
# Saving data from  70
# Saving data from  71
# Saving data from  72
# Saving data from  73
# Saving data from  74
# Saving data from  75
# Saving data from  76
# Saving data from  77
# Saving data from  78
# Saving data from  79
# Saving data from  80
# Saving data from  81
# Saving data from  82
# Saving data from  83
# Saving data from  84
# Saving data from  85
# Saving data from  86
# Saving data from  87
# Saving data from  88
# Saving data from  89
# Saving data from  90
# Saving data from  91
# Saving data from  92
# Saving data from  93
# Saving data from  94
# Saving data from  95
# Saving data from  96
# Saving data from  97
# Saving data from  98
# Saving data from  99
# Saving data from  100

# %%
# curl -H "Authorization: Bearer {YOUR_ACCESS_TOKEN}" GET https://api.petfinder.com/v2/{CATEGORY}/{ACTION}?{parameter_1}={value_1}&{parameter_2}={value_2}

# category = animals | types | organizations
# parameters = type | breed | size | gender | age | color | coat | status | name | organization | location | distance | sort | page | limit


################### Option 1 - Cats by pages###########################

import time 
import pymongo
import json

#data_query_url_base = "https://api.petfinder.com/v2/animals?type=dog&limit=100"
data_query_url_base = "https://api.petfinder.com/v2/animals?type=cat&limit=100"

mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
#mongo_client = pymongo.MongoClient("mongodb+srv://k9sam:1234@petfinder-qbryn.mongodb.net/test?retryWrites=true")

# mongoDB db name = pets
mongo_pet_db = mongo_client['pets'] 
mongo_pet_collection = mongo_pet_db["cats_by_page"]


for i in range(100):
    page_parameter = "&page=" + str(i+1)
    data_query_url = data_query_url_base + page_parameter
  
    headers = {
        'Authorization': 'Bearer {}'.format(access_token),
    }

    response = requests.get(data_query_url, headers=headers).json()
    
        # json cleaning
    data = response["animals"]
    
    for item in data:
        
        url = item["url"]
        species = item["species"]
        breed = item["breeds"]["primary"]
        color = item["colors"]["primary"]
        age = item["age"]
        gender = item["gender"]
        size = item["size"]
        coat = item["coat"]
        spayed_neutered = item["attributes"]["spayed_neutered"]
        house_trained = item["attributes"]["house_trained"]
        declawed = item["attributes"]["declawed"]
        special_needs = item["attributes"]["special_needs"]
        shots = item["attributes"]["shots_current"]
        name = item["name"]
        description = item["description"]
        
        if len(item["photos"]) != 0:
            photo = item["photos"][0]["full"]
        else:
            photo = "NULL"        
        
        status = item["status"]
        publish_date = item["published_at"]
        contact_email = item["contact"]["email"]
        contact_phone = item["contact"]["phone"]
        contact_address1 = item["contact"]["address"]["address1"]
        contact_address2 = item["contact"]["address"]["address2"]
        contact_city = item["contact"]["address"]["city"]
        contact_state = item["contact"]["address"]["state"]
        contact_postcode = item["contact"]["address"]["postcode"]
        contact_country = item["contact"]["address"]["country"]
    
        data_dict = {
        "url" : url,
        "species" : species,
        "breed" : breed,
        "color" : color,
        "age" : age,
        "gender" : gender,
        "size" : size,
        "coat" : coat,
        "spayed_neutered" : spayed_neutered,
        "house_trained" : house_trained,
        "declawed" : declawed,
        "special_needs" : special_needs,
        "shots" : shots,
        "name" : name,
        "description" : description,
        "photo" : photo,
        "status" : status,
        "publish_date" : publish_date,
        "contact_email" : contact_email,
        "contact_phone" : contact_phone,
        "contact_address1" : contact_address1,
        "contact_address2" : contact_address2,
        "contact_city" : contact_city,
        "contact_state" : contact_state,
        "contact_postcode" : contact_postcode,
        "contact_country" : contact_country
        }
        
        # Save to json file
        with open("cats_by_page.json", "a") as json_file:
            json.dump(data_dict, json_file)
    
        # save dataFrame to mongoDB
        mongo_pet_collection.insert(data_dict)
        
    #mongo_pet_collection.insert(response["animals"])
    
    print("Saving data from page {}".format(i+1))
        
    time.sleep(2)

    
############# end of option 1 (cats by page)########################
# Out:
# C:\Users\bbmerci\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:105: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# Saving data from page 1
# Saving data from page 2
# Saving data from page 3
# Saving data from page 4
# Saving data from page 5
# Saving data from page 6
# Saving data from page 7
# Saving data from page 8
# Saving data from page 9
# Saving data from page 10
# Saving data from page 11
# Saving data from page 12
# Saving data from page 13
# Saving data from page 14
# Saving data from page 15
# Saving data from page 16
# Saving data from page 17
# Saving data from page 18
# Saving data from page 19
# Saving data from page 20
# Saving data from page 21
# Saving data from page 22
# Saving data from page 23
# Saving data from page 24
# Saving data from page 25
# Saving data from page 26
# Saving data from page 27
# Saving data from page 28
# Saving data from page 29
# Saving data from page 30
# Saving data from page 31
# Saving data from page 32
# Saving data from page 33
# Saving data from page 34
# Saving data from page 35
# Saving data from page 36
# Saving data from page 37
# Saving data from page 38
# Saving data from page 39
# Saving data from page 40
# Saving data from page 41
# Saving data from page 42
# Saving data from page 43
# Saving data from page 44
# Saving data from page 45
# Saving data from page 46
# Saving data from page 47
# Saving data from page 48
# Saving data from page 49
# Saving data from page 50
# Saving data from page 51
# Saving data from page 52
# Saving data from page 53
# Saving data from page 54
# Saving data from page 55
# Saving data from page 56
# Saving data from page 57
# Saving data from page 58
# Saving data from page 59
# Saving data from page 60
# Saving data from page 61
# Saving data from page 62
# Saving data from page 63
# Saving data from page 64
# Saving data from page 65
# Saving data from page 66
# Saving data from page 67
# Saving data from page 68
# Saving data from page 69
# Saving data from page 70
# Saving data from page 71
# Saving data from page 72
# Saving data from page 73
# Saving data from page 74
# Saving data from page 75
# Saving data from page 76
# Saving data from page 77
# Saving data from page 78
# Saving data from page 79
# Saving data from page 80
# Saving data from page 81
# Saving data from page 82
# Saving data from page 83
# Saving data from page 84
# Saving data from page 85
# Saving data from page 86
# Saving data from page 87
# Saving data from page 88
# Saving data from page 89
# Saving data from page 90
# Saving data from page 91
# Saving data from page 92
# Saving data from page 93
# Saving data from page 94
# Saving data from page 95
# Saving data from page 96
# Saving data from page 97
# Saving data from page 98
# Saving data from page 99
# Saving data from page 100
