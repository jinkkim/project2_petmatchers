# %%
import pandas as pd
import numpy as np
from flask_pymongo import PyMongo
from flask import Flask, render_template
from bson.json_util import dumps

app = Flask(__name__)

# Database Setup
app.config["MONGO_URI"] = "mongodb+srv://k9sam:1234@petfinder-qbryn.mongodb.net/pets"
mongo = PyMongo(app)
db_dogData = mongo.db.dogs_by_page
db_catData = mongo.db.cats_by_page
db_cost = mongo.db.annual_costs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ad02a4d2e6f2> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from flask_pymongo import PyMongo
#       4 from flask import Flask, render_template
#       5 from bson.json_util import dumps
#
# ModuleNotFoundError: No module named 'flask_pymongo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
db_dogData.distinct("age")
# Out:
# ['Adult', 'Young', 'Baby', 'Senior']

# %%
df_dogData = pd.DataFrame(list(db_dogData.find()))

# %%
state_info = df_dogData.groupby("contact_state")["_id"].count()
# Out:
# breed
# Labrador Retriever     1177
# Pit Bull Terrier       1014
# Chihuahua               858
# Mixed Breed             607
# Terrier                 488
# German Shepherd Dog     466
# Shepherd                329
# Beagle                  284
# Boxer                   282
# Hound                   249
# Name: _id, dtype: int64

# %%
list(breed_count[0:10].keys())
# Out:
# ['Labrador Retriever',
#  'Pit Bull Terrier',
#  'Chihuahua',
#  'Mixed Breed',
#  'Terrier',
#  'German Shepherd Dog',
#  'Shepherd',
#  'Beagle',
#  'Boxer',
#  'Hound']

# %%
from states_covert import states_convert

# %%
state_info = df_dogData.groupby("contact_state")["_id"].count()

# %%
US_state_info = df_dogData[df_dogData["contact_country"] == "US"].groupby("contact_state")["_id"].count()
US_state_info
# Out:
# contact_state
# AK       3
# AL     159
# AR      71
# AZ     348
# CA    1218
# CO     261
# CT     118
# DC      52
# DE      16
# FL     579
# GA     469
# GU       3
# HI       9
# IA      72
# ID      39
# IL     395
# IN     209
# KS     131
# KY     213
# LA      75
# MA     115
# MD     138
# ME      24
# MI     209
# MN     191
# MO     301
# MS      90
# MT      11
# NC     253
# ND      13
# NE      36
# NH      30
# NJ     185
# NM     101
# NV     131
# NY     330
# OH     325
# OK     204
# OR     123
# PA     229
# PR       5
# RI      60
# SC     192
# SD      10
# TN     232
# TX    1263
# UT      68
# VA     175
# VT      26
# WA     175
# WI     194
# WV      40
# WY      24
# Name: _id, dtype: int64

# %%
state_names = list(US_state_info.keys())
state_name_converted = []

# %%
for state in state_names:
    state_name_converted.append(states_convert[state])
state_name_converted
# Out:
# ['Alaska',
#  'Alabama',
#  'Arkansas',
#  'Arizona',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'District of Columbia',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Guam',
#  'Hawaii',
#  'Iowa',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Massachusetts',
#  'Maryland',
#  'Maine',
#  'Michigan',
#  'Minnesota',
#  'Missouri',
#  'Mississippi',
#  'Montana',
#  'North Carolina',
#  'North Dakota',
#  'Nebraska',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'Nevada',
#  'New York',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Puerto Rico',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Virginia',
#  'Vermont',
#  'Washington',
#  'Wisconsin',
#  'West Virginia',
#  'Wyoming']

# %%
state_count = list(US_state_info)
dog_population = {}
for i in range(len(state_names)):
    dog_population.update({state_name_converted[i]:state_count[i] })
dog_population
# Out:
# {'Alaska': 3,
#  'Alabama': 159,
#  'Arkansas': 71,
#  'Arizona': 348,
#  'California': 1218,
#  'Colorado': 261,
#  'Connecticut': 118,
#  'District of Columbia': 52,
#  'Delaware': 16,
#  'Florida': 579,
#  'Georgia': 469,
#  'Guam': 3,
#  'Hawaii': 9,
#  'Iowa': 72,
#  'Idaho': 39,
#  'Illinois': 395,
#  'Indiana': 209,
#  'Kansas': 131,
#  'Kentucky': 213,
#  'Louisiana': 75,
#  'Massachusetts': 115,
#  'Maryland': 138,
#  'Maine': 24,
#  'Michigan': 209,
#  'Minnesota': 191,
#  'Missouri': 301,
#  'Mississippi': 90,
#  'Montana': 11,
#  'North Carolina': 253,
#  'North Dakota': 13,
#  'Nebraska': 36,
#  'New Hampshire': 30,
#  'New Jersey': 185,
#  'New Mexico': 101,
#  'Nevada': 131,
#  'New York': 330,
#  'Ohio': 325,
#  'Oklahoma': 204,
#  'Oregon': 123,
#  'Pennsylvania': 229,
#  'Puerto Rico': 5,
#  'Rhode Island': 60,
#  'South Carolina': 192,
#  'South Dakota': 10,
#  'Tennessee': 232,
#  'Texas': 1263,
#  'Utah': 68,
#  'Virginia': 175,
#  'Vermont': 26,
#  'Washington': 175,
#  'Wisconsin': 194,
#  'West Virginia': 40,
#  'Wyoming': 24}

# %%
import json

# %%
a = { "species": "Dog", "breed": "Pit Bull Terrier", "size": "", "gender": "Male", "age": "Young" }
a
# Out:
# {'age': 'Young',
#  'breed': 'Pit Bull Terrier',
#  'gender': 'Male',
#  'size': '',
#  'species': 'Dog'}

# %%
b = [{k:v} for k,v in a.items() if v != ""]
b
# Out:
# [{'species': 'Dog'},
#  {'breed': 'Pit Bull Terrier'},
#  {'gender': 'Male'},
#  {'age': 'Young'}]
